# %% [markdown]
# ### 1 数据预处理

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.1 数据加载

# %%
df = pd.read_csv("./data/sales.csv", encoding="gbk")
df
# Out:
#           时间  销售额（万元）
# 0    2004年1月      740
# 1    2004年2月      745
# 2    2004年3月      746
# 3    2004年4月      780
# 4    2004年5月      784
# 5    2004年6月      785
# 6    2004年7月      793
# 7    2004年8月      792
# 8    2004年9月      785
# 9   2004年10月      782
# 10  2004年11月      789
# 11  2004年12月      793
# 12   2005年1月      795
# 13   2005年2月      790
# 14   2005年3月      796
# 15   2005年4月      810
# 16   2005年5月      830
# 17   2005年6月      843
# 18   2005年7月      843
# 19   2005年8月      852
# 20   2005年9月      854
# 21  2005年10月      860
# 22  2005年11月      859
# 23  2005年12月      864
# 24   2006年1月      865
# 25   2006年2月      854
# 26   2006年3月      850
# 27   2006年4月      855
# 28   2006年5月      862
# 29   2006年6月      864
# 30   2006年7月      870
# 31   2006年8月      875
# 32   2006年9月      880
# 33  2006年10月      888
# 34  2006年11月      879
# 35  2006年12月      897
# 36   2007年1月      900
# 37   2007年2月      887
# 38   2007年3月      890
# 39   2007年4月      893
# ...

# %%
df.columns
# Out:
# Index(['时间', '销售额（万元）'], dtype='object')

# %%
df.columns = ["time", "amount"]
df.head()
# Out:
#       time  amount
# 0  2004年1月     740
# 1  2004年2月     745
# 2  2004年3月     746
# 3  2004年4月     780
# 4  2004年5月     784

# %% [markdown]
# #### 1.2 将时间进行日期类型转换

# %%
df.time = pd.to_datetime(df.time, format="%Y年%m月")
df.head()
# Out:
#         time  amount
# 0 2004-01-01     740
# 1 2004-02-01     745
# 2 2004-03-01     746
# 3 2004-04-01     780
# 4 2004-05-01     784

# %% [markdown]
# #### 1.3 将时间作为df的索引

# %%
df.index = df.time
df.head()
# Out:
#                  time  amount
# time
# 2004-01-01 2004-01-01     740
# 2004-02-01 2004-02-01     745
# 2004-03-01 2004-03-01     746
# 2004-04-01 2004-04-01     780
# 2004-05-01 2004-05-01     784

# %% [markdown]
# ### 2 采用ARIMA模型

# %%
from itertools import product
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2.1 设置参数范围

# %%
ps = range(0, 5)
qs = range(0, 5)
ds = range(1, 5)

# %%
parameters = product(ps, ds, qs)
parameters_list = list(parameters)

# %%
parameters_list[:5]
# Out:
# [(0, 1, 0), (0, 1, 1), (0, 1, 2), (0, 1, 3), (0, 1, 4)]

# %% [markdown]
# #### 2.2寻找最优ARIMA模型参数

# %%
results = []
best_aic = float("inf") # 正无穷

# %%
# %%time
for param in parameters_list:
    try:
        model = sm.tsa.statespace.SARIMAX(df.amount,
                                order=(param[0], param[1], param[2]),
                                enforce_stationarity=False,
                                enforce_invertibility=False).fit()

    except ValueError:
        print('参数错误:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    print("参数: ", param, "训练完成")
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ...

# %%
print('最优模型: ', best_model.summary())
# Out:
# 最优模型:                                 SARIMAX Results
# ...
# Dep. Variable:                 amount   No. Observations:                   42
# Model:               SARIMAX(0, 2, 4)   Log Likelihood                -122.322
# Date:                Sat, 23 Jan 2021   AIC                            254.643
# Time:                        09:05:37   BIC                            262.420
# Sample:                    01-01-2004   HQIC                           257.328
#                          - 06-01-2007
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7543   2145.672     -0.000      1.000   -4206.193    4204.685
# ma.L2         -0.3727    527.114     -0.001      0.999   -1033.496    1032.751
# ma.L3          0.2205    272.436      0.001      0.999    -533.744     534.185
# ...

# %% [markdown]
# #### 2.3 预测后4个月

# %%
predict_y = best_model.get_prediction(start=0, end=len(df.amount)+4-1).predicted_mean

# %%
predict_y.name = "forecast"

# %%
df = pd.concat([df, predict_y], axis=1)
df
# Out:
#                  time  amount     forecast
# 2004-01-01 2004-01-01   740.0     0.000000
# 2004-02-01 2004-02-01   745.0  1233.333333
# 2004-03-01 2004-03-01   746.0   750.013111
# 2004-04-01 2004-04-01   780.0   747.006590
# 2004-05-01 2004-05-01   784.0   813.995209
# 2004-06-01 2004-06-01   785.0   788.001595
# 2004-07-01 2004-07-01   793.0   786.980973
# 2004-08-01 2004-08-01   792.0   799.030618
# 2004-09-01 2004-09-01   785.0   792.725167
# 2004-10-01 2004-10-01   782.0   785.838921
# 2004-11-01 2004-11-01   789.0   782.045757
# 2004-12-01 2004-12-01   793.0   791.998282
# 2005-01-01 2005-01-01   795.0   793.825378
# 2005-02-01 2005-02-01   790.0   797.605956
# 2005-03-01 2005-03-01   796.0   789.249362
# 2005-04-01 2005-04-01   810.0   800.315946
# 2005-05-01 2005-05-01   830.0   813.419909
# 2005-06-01 2005-06-01   843.0   837.364536
# 2005-07-01 2005-07-01   843.0   847.725875
# 2005-08-01 2005-08-01   852.0   846.919652
# 2005-09-01 2005-09-01   854.0   858.920256
# ...

# %% [markdown]
# 前两个点预估异常，将其取消

# %%
df["forecast"][:2] = [None, None]
df["time"][:2] = [None, None]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                            time  amount forecast
# 2004-01-01                 None   740.0     None
# 2004-02-01                 None   745.0     None
# 2004-03-01  1078099200000000000   746.0  750.013
# 2004-04-01  1080777600000000000   780.0  747.007
# 2004-05-01  1083369600000000000   784.0  813.995
# 2004-06-01  1086048000000000000   785.0  788.002
# 2004-07-01  1088640000000000000   793.0  786.981
# 2004-08-01  1091318400000000000   792.0  799.031
# 2004-09-01  1093996800000000000   785.0  792.725
# 2004-10-01  1096588800000000000   782.0  785.839
# 2004-11-01  1099267200000000000   789.0  782.046
# 2004-12-01  1101859200000000000   793.0  791.998
# 2005-01-01  1104537600000000000   795.0  793.825
# 2005-02-01  1107216000000000000   790.0  797.606
# 2005-03-01  1109635200000000000   796.0  789.249
# 2005-04-01  1112313600000000000   810.0  800.316
# 2005-05-01  1114905600000000000   830.0   813.42
# 2005-06-01  1117584000000000000   843.0  837.365
# ...

# %%
plt.figure(figsize=(50, 25))
df.amount.plot(label="Real Sales")
df.forecast.plot(color="r", ls="--", label="Sales Prediction")
plt.legend()
plt.title("SuperMaket Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
